# %%
import pandas as pd

df = pd.read_excel (r'Desktop/payment.xlsx')
print (df)
# Out:
#   Enter your email address  \
# 0  salhaalmawali@gmail.com
# 1            anu@gmail.com
# 2     ruruti2112@gmail.com
#
#    How many children are studying in Ahmad bin Majid Private School?  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
#
#   Please select your fees payment option      Parent Full Name       Date  \
# 0                     Three installments  Salha Saud Al Mawali 2021-06-22
# 1                       Two installments           Anumanjusha 2021-06-22
# 2                     Three installments        salha almawali 2021-06-23
#
#              Email address  Select the class and number of children [KG 1]  \
# 0  salhaalmawali@gmail.com                                             NaN
# 1                      NaN                                             NaN
# 2                      NaN                                             NaN
#
# ...

# %%
display(df)
# Out:
#   Enter your email address  \
# 0  salhaalmawali@gmail.com
# 1            anu@gmail.com
# 2     ruruti2112@gmail.com
#
#    How many children are studying in Ahmad bin Majid Private School?  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
#
#   Please select your fees payment option      Parent Full Name       Date  \
# 0                     Three installments  Salha Saud Al Mawali 2021-06-22
# 1                       Two installments           Anumanjusha 2021-06-22
# 2                     Three installments        salha almawali 2021-06-23
#
#              Email address  Select the class and number of children [KG 1]  \
# 0  salhaalmawali@gmail.com                                             NaN
# 1                      NaN                                             NaN
# 2                      NaN                                             NaN
#
# ...

# %%
df_t = df.T
print(df_t)
# Out:
#                                                                           0  \
# Enter your email address                            salhaalmawali@gmail.com
# How many children are studying in Ahmad bin Maj...                        3
# Please select your fees payment option                   Three installments
# Parent Full Name                                       Salha Saud Al Mawali
# Date                                                    2021-06-22 00:00:00
# Email address                                       salhaalmawali@gmail.com
# Select the class and number of children [KG 1]                          NaN
# Select the class and number of children [KG 2]                          NaN
# Select the class and number of children [Class 1]                         1
# Select the class and number of children [Class 2]                       NaN
# Select the class and number of children [Class 3]                       NaN
# ...

# %%
display(df_t)
# Out:
#                                                                           0  \
# Enter your email address                            salhaalmawali@gmail.com
# How many children are studying in Ahmad bin Maj...                        3
# Please select your fees payment option                   Three installments
# Parent Full Name                                       Salha Saud Al Mawali
# Date                                                    2021-06-22 00:00:00
# Email address                                       salhaalmawali@gmail.com
# Select the class and number of children [KG 1]                          NaN
# Select the class and number of children [KG 2]                          NaN
# Select the class and number of children [Class 1]                         1
# Select the class and number of children [Class 2]                       NaN
# Select the class and number of children [Class 3]                       NaN
# ...

# %%
p=df_t.head(24)
display(p)
# Out:
#                                                                           0  \
# Enter your email address                            salhaalmawali@gmail.com
# How many children are studying in Ahmad bin Maj...                        3
# Please select your fees payment option                   Three installments
# Parent Full Name                                       Salha Saud Al Mawali
# Date                                                    2021-06-22 00:00:00
# Email address                                       salhaalmawali@gmail.com
# Select the class and number of children [KG 1]                          NaN
# Select the class and number of children [KG 2]                          NaN
# Select the class and number of children [Class 1]                         1
# Select the class and number of children [Class 2]                       NaN
# Select the class and number of children [Class 3]                       NaN
# ...

# %%
for name, values in df.iteritems():
    print('{name}: {value}'.format(name=name, value=values[0]))
# Out:
# Enter your email address: salhaalmawali@gmail.com
# How many children are studying in Ahmad bin Majid Private School?: 3
# Please select your fees payment option: Three installments
# Parent Full Name: Salha Saud Al Mawali
# Date: 2021-06-22 00:00:00
# Email address: salhaalmawali@gmail.com
# Select the class and number of children [KG 1]: nan
# Select the class and number of children [KG 2]: nan
# Select the class and number of children [Class 1]: 1.0
# Select the class and number of children [Class 2]: nan
# Select the class and number of children [Class 3]: nan
# Select the class and number of children [class 4]: 1.0
# Select the class and number of children [Class 5]: nan
# Select the class and number of children [Class 6]: nan
# Select the class and number of children [Class 7]: nan
# Select the class and number of children [Class 8]: nan
# Select the class and number of children [Class 9]: nan
# Select the class and number of children [Class 10]: 1.0
# ...

# %%
import pandas as pd

df = pd.read_excel (r'Desktop/payment.xlsx')
display(df)
# Out:
#   Enter your email address  \
# 0  salhaalmawali@gmail.com
# 1            anu@gmail.com
# 2     ruruti2112@gmail.com
#
#    How many children are studying in Ahmad bin Majid Private School?  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
#
#   Please select your fees payment option      Parent Full Name       Date  \
# 0                     Three installments  Salha Saud Al Mawali 2021-06-22
# 1                       Two installments           Anumanjusha 2021-06-22
# 2                     Three installments        salha almawali 2021-06-23
#
#              Email address  Select the class and number of children [KG 1]  \
# 0  salhaalmawali@gmail.com                                             NaN
# 1                      NaN                                             NaN
# 2                      NaN                                             NaN
#
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df3 = pd.read_excel (r'Desktop/payment.xlsx', sheet_name='Form responses 1')
print(df)
# Out:
#   Enter your email address  \
# 0  salhaalmawali@gmail.com
# 1            anu@gmail.com
# 2     ruruti2112@gmail.com
#
#    How many children are studying in Ahmad bin Majid Private School?  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
#
#   Please select your fees payment option      Parent Full Name       Date  \
# 0                     Three installments  Salha Saud Al Mawali 2021-06-22
# 1                       Two installments           Anumanjusha 2021-06-22
# 2                     Three installments        salha almawali 2021-06-23
#
#              Email address  Select the class and number of children [KG 1]  \
# 0  salhaalmawali@gmail.com                                             NaN
# 1                      NaN                                             NaN
# 2                      NaN                                             NaN
#
# ...

# %%
import pandas as pd

data = pd.read_excel (r'Desktop/paymentt.xlsx') 

df= data.T
display(df)
# Out:
#                                                                           0  \
# Enter your email address                            salhaalmawali@gmail.com
# How many children are studying in Ahmad bin Maj...                        3
# Please select your fees payment option                   Three installments
# Parent Full Name                                       Salha Saud Al Mawali
#
#                                                                    1  \
# Enter your email address                               anu@gmail.com
# How many children are studying in Ahmad bin Maj...                 4
# Please select your fees payment option              Two installments
# Parent Full Name                                         Anumanjusha
#
#                                                                        2
# Enter your email address                            ruruti2112@gmail.com
# How many children are studying in Ahmad bin Maj...                     3
# ...

# %%
# Rename the columns of df2_melted: df2_tidy
df2= data.rename(columns = {'Enter your email address': 'Email', 
                           'How many children are studying in Ahmad bin Majid Private School?': 'Children No.',
                           'Please select your fees payment option': 'payment installments'}, inplace = False)

display(df2)
# Out:
#                      Email  Children No. payment installments  \
# 0  salhaalmawali@gmail.com             3   Three installments
# 1            anu@gmail.com             4     Two installments
# 2     ruruti2112@gmail.com             3   Three installments
#
#        Parent Full Name
# 0  Salha Saud Al Mawali
# 1           Anumanjusha
# 2        salha almawali

# %%
df = pd.DataFrame(data, columns= ['Parent Full Name'])
for i in df2.values:
    
    print (i)
# Out:
# ['salhaalmawali@gmail.com' 3 'Three installments' 'Salha Saud Al Mawali']
# ['anu@gmail.com' 4 'Two installments' 'Anumanjusha']
# ['ruruti2112@gmail.com' 3 'Three installments' 'salha almawali']

# %%
import pandas as pd

read_file = pd.read_excel (r'Desktop/pay.xlsx')
read_file.to_csv (r'Desktop/payment.csv', index = None, header=True)

# %%
students_payment = pd.read_csv(r'Desktop/payment.csv')
print(students_payment)
# Out:
#   Enter your email address  \
# 0  salhaalmawali@gmail.com
# 1            anu@gmail.com
# 2     ruruti2112@gmail.com
#
#    How many children are studying in Ahmad bin Majid Private School?  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
#
#   Please select your fees payment option      Parent Full Name        Date  \
# 0                     Three installments  Salha Saud Al Mawali  2021-06-22
# 1                       Two installments           Anumanjusha  2021-06-22
# 2                     Three installments        salha almawali  2021-06-23
#
#              Email address  Select the class and number of children [KG 1]  \
# 0  salhaalmawali@gmail.com                                             NaN
# 1                      NaN                                             NaN
# 2                      NaN                                             NaN
#
# ...

# %%
import pandas as pd
df_data = pd.read_excel (r'Desktop/pay.xlsx')
df = pd.DataFrame(df_data)
df.replace('NaN', ' ')
# Out:
#   Enter your email address  \
# 0  salhaalmawali@gmail.com
# 1            anu@gmail.com
# 2     ruruti2112@gmail.com
#
#    How many children are studying in Ahmad bin Majid Private School?  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
#
#   Please select your fees payment option      Parent Full Name       Date  \
# 0                     Three installments  Salha Saud Al Mawali 2021-06-22
# 1                       Two installments           Anumanjusha 2021-06-22
# 2                     Three installments        salha almawali 2021-06-23
#
#              Email address  Select the class and number of children [KG 1]  \
# 0  salhaalmawali@gmail.com                                             NaN
# 1                      NaN                                             NaN
# 2                      NaN                                             NaN
#
# ...

# %%
import numpy as np
import pandas as pd

 # reading and Creating a DataFrame from excel sheet
data = pd.read_excel(r'Desktop/school.xlsx')
#gfg = pd.DataFrame(df_data)
  
#Finding the mean of the column having NaN
#mean_value=gfg['Email address'].mean()
  
# Replace NaNs in column S2 with the
# mean of values in the same column
#gfg.fillna(' ', inplace=True)
#print(' Dataframe:')
#print()
#gfg_updated = pd.DataFrame(gfg)
print(data )
# Out:
#                           Email  number of children     payment options  \
# 0         hereisemail@gmail.com                   3     One installment
# 1  hereisAnotheremail@gmail.com                   2  Eight installments
# 2        Anotheremail@gmail.com                   3     One installment
# 3               email@gmail.com                   3  Three installments
# 4       anotherParent@gmail.com                   2  Eight installments
# 5         munchkin99x@gmail.com                   1     One installment
#
#   class of child1 class of child2 (If any) class of child3( If any)
# 0             KG1                  Class 3                 Class 11
# 1             KG2                  Class 7                     None
# 2         Class 1                 Class 11                 Class 12
# 3         Class 3                  Class 6                 Class 12
# 4         Class 6                  Class 6                     None
# ...

# %%
entry_list=[]
ent=[]

for i,n in data.items():
   
    ent=i

    entry_list.append(entry)
print(entry_list)
# Out:
# ['class of child3( If any)', 'class of child3( If any)', 'class of child3( If any)', 'class of child3( If any)', 'class of child3( If any)', 'class of child3( If any)']

# %%
import pandas as pd

df = pd.read_excel('Desktop/school.xlsx') # can also index sheet by name or fetch all sheets
emails_list = df['Email'].tolist()
#print(emails)

numOfChildren_list=df['number of children'].tolist()
#print(numOfChildren_list)

paymentOptions_list=df['payment options'].tolist()
#print(paymentOptions_list)

c1_list=df['class of child1'].tolist()
#print(c1_list)

c2_list=df['class of child2 (If any)'].tolist()
#print(c2_list)

c3_list=df['class of child3( If any)'].tolist()
#print(c3_list)

# %%
for entry in range(len(emails_list)):
    for i in emails_list:
        print(i)
       # print(numOfChildren_list[i])
# Out:
# hereisemail@gmail.com
# hereisAnotheremail@gmail.com
# Anotheremail@gmail.com
# email@gmail.com
# anotherParent@gmail.com
# munchkin99x@gmail.com
# hereisemail@gmail.com
# hereisAnotheremail@gmail.com
# Anotheremail@gmail.com
# email@gmail.com
# anotherParent@gmail.com
# munchkin99x@gmail.com
# hereisemail@gmail.com
# hereisAnotheremail@gmail.com
# Anotheremail@gmail.com
# email@gmail.com
# anotherParent@gmail.com
# munchkin99x@gmail.com
# hereisemail@gmail.com
# hereisAnotheremail@gmail.com
# Anotheremail@gmail.com
# email@gmail.com
# anotherParent@gmail.com
# munchkin99x@gmail.com
# hereisemail@gmail.com
# hereisAnotheremail@gmail.com
# Anotheremail@gmail.com
# email@gmail.com
# anotherParent@gmail.com
# munchkin99x@gmail.com
# hereisemail@gmail.com
# hereisAnotheremail@gmail.com
# Anotheremail@gmail.com
# email@gmail.com
# anotherParent@gmail.com
# munchkin99x@gmail.com
